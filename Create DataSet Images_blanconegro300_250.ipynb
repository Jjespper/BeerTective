# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import cv2
import pandas as pd
import pickle

# %%
DataDir = "/home/jjespper/masterIronhack/Categorias_Cervezas"

categories = ['Amstel', 'Cruzcampo', 'Estrella_damm', 'Estrella_galicia', 
              'Franziskaner', 'Heineken','Mahou', 'Pilsen_urquell','Sanmiguel']

# %%
img_ancho = 250
img_alto = 300

# %%
def create_training_data(categorylist,ancho,alto):
    lst=[]

    for category in categorylist:
        path = os.path.join(DataDir, category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (ancho, alto))
                new_array = cv2.cvtColor(new_array, cv2.COLOR_BGR2GRAY)
                plt.imshow(new_array)
                plt.show
                lst.append((new_array, class_num))
            except Exception as e:
                pass
    return lst
training_data = create_training_data(categories,img_ancho,img_alto)

# %%
import random
random.shuffle(training_data)

# %%
X=[]
y=[]
for features, label in training_data:
    X.append(features)
    y.append(label)
X = np.array(X).reshape(-1, 300, 250, 1)

# %%
X.shape
# Out:
# (1227, 300, 250, 1)

# %%
len(y)
# Out:
# 1227

# %%
pickle_out = open("X.pickle_blackwhite_300_250", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle_blackwhite_300_250", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
asd = open("X.pickle_blackwhite_300_250", "rb")

# %%
equis = pickle.load(asd)

# %%
equis.shape
# Out:
# (1227, 300, 250, 1)
