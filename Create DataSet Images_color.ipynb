# %%
import numpy as np
import matplotlib.pyplot as plt
import os 
import cv2
import pandas as pd
import pickle

# %%
DataDir = "/home/jjespper/masterIronhack/Prueba_camara"

categories = ['Budweiser', 'Mahou', 'Pilsen_urquell','San_miguel']

# %%
img_ancho = 200
img_alto = 200

# %%
def create_training_data(categorylist,ancho,alto):
    lst=[]

    for category in categorylist:
        path = os.path.join(DataDir, category)
        class_num = categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (ancho, alto))
                new_array = cv2.cvtColor(new_array, cv2.COLOR_BGR2GRAY)
                plt.imshow(new_array)
                plt.show
                lst.append((new_array, class_num))
            except Exception as e:
                pass
    return lst
training_data = create_training_data(categories,img_ancho,img_alto)

# %%
import random
random.shuffle(training_data)

# %%
X=[]
y=[]
for features, label in training_data:
    X.append(features)
    y.append(label)
X = np.array(X).reshape(-1, 200, 200, 1)

# %%
len(X)
# Out:
# 1638

# %%
len(y)
# Out:
# 1638

# %%
pickle_out = open("X.pickle_encasa", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle_encasa", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()

# %%
asd = open("X.pickle_encasa", "rb")

# %%
equis = pickle.load(asd)

# %%
equis.shape
# Out:
# (1638, 200, 200, 1)
